# %% [markdown]
# Praticando machine learning para prever dados

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import ExtraTreesClassifier
arquivo = pd.read_csv('wine_dataset.csv')
arquivo.head()
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality style
# 0      9.4        5   red
# 1      9.8        5   red
# ...

# %% [markdown]
# Substituindo no arquivo os dados da coluna style de red ou white para 0 ou 1 respectivamente

# %%
arquivo['style']=arquivo['style'].replace('red',0)
arquivo['style']=arquivo['style'].replace('white',1)

# %%
arquivo
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 6492            6.2              0.21         0.29             1.6      0.039
# 6493            6.6              0.32         0.36             8.0      0.047
# 6494            6.5              0.24         0.19             1.2      0.041
# 6495            5.5              0.29         0.30             1.1      0.022
# 6496            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
y= arquivo['style']
x= arquivo.drop('style',axis=1)

# %% [markdown]
# Utilizando a função train_test_split para separar as variáveis de treino e teste, utilizando 70% dos dados para treino

# %%
x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size = 0.3)

# %% [markdown]
# Utilizando o ExtraTreesClassifier que criará árvores de decisão. O método fit utiliza os dados predidores e os 'targets' para entender a relação entre os dados e o score utiliza os dados de teste para saber a precisão dessa relação.

# %%
modelo = ExtraTreesClassifier()
modelo.fit(x_treino, y_treino)
resultado = modelo.score(x_teste, y_teste)
print("Acurácia:", resultado)
# Out:
# Acurácia: 0.9948717948717949

# %%
y_teste[300:309]
# Out:
# 2950    1
# 6180    1
# 5776    1
# 1306    0
# 6412    1
# 5646    1
# 2138    1
# 4093    1
# 1451    0
# Name: style, dtype: int64

# %%
previsoes = modelo.predict(x_teste[300:309])
print(previsoes)
# Out:
# [1 1 1 0 1 1 1 1 0]
